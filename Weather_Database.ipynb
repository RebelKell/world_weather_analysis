# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
     # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather" : city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | hanamaki
# Processing Record 4 of Set 1 | rio de janeiro
# Processing Record 5 of Set 1 | muros
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | abha
# Processing Record 8 of Set 1 | pangnirtung
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | namibe
# Processing Record 13 of Set 1 | padang
# Processing Record 14 of Set 1 | nouadhibou
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | ancud
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | pevek
# Processing Record 20 of Set 1 | port blair
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | half moon bay
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | asau
# Processing Record 25 of Set 1 | zermatt
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | klaksvik
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | gizo
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | fukue
# Processing Record 32 of Set 1 | vostok
# Processing Record 33 of Set 1 | tuatapere
# Processing Record 34 of Set 1 | valparaiso
# Processing Record 35 of Set 1 | praia
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | salalah
# Processing Record 39 of Set 1 | katsuura
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | longyearbyen
# Processing Record 44 of Set 1 | coahuayana
# Processing Record 45 of Set 1 | srandakan
# Processing Record 46 of Set 1 | myingyan
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | dolores
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | jacareacanga
# Processing Record 1 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 2 | pavlogradka
# Processing Record 5 of Set 2 | tutoia
# Processing Record 6 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | culebra
# Processing Record 9 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 2 | aksarka
# Processing Record 11 of Set 2 | jurado
# Processing Record 12 of Set 2 | ponta delgada
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | glendive
# Processing Record 15 of Set 2 | iwaki
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | cidreira
# Processing Record 20 of Set 2 | hamilton
# Processing Record 21 of Set 2 | riberalta
# Processing Record 22 of Set 2 | satipo
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | sobradinho
# Processing Record 26 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 2 | honningsvag
# Processing Record 28 of Set 2 | grinnell
# Processing Record 29 of Set 2 | zyryanovsk
# Processing Record 30 of Set 2 | oranjestad
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | talcahuano
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | necochea
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | caravelas
# Processing Record 37 of Set 2 | oranjemund
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | khor
# Processing Record 40 of Set 2 | mataura
# Processing Record 41 of Set 2 | hofn
# Processing Record 42 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 2 | baykit
# Processing Record 44 of Set 2 | puerto madero
# Processing Record 45 of Set 2 | los llanos de aridane
# Processing Record 46 of Set 2 | lubana
# Processing Record 47 of Set 2 | coihaique
# Processing Record 48 of Set 2 | sinobong
# City not found. Skipping...
# Processing Record 49 of Set 2 | komsomolskiy
# Processing Record 50 of Set 2 | saint-francois
# Processing Record 1 of Set 3 | sinnamary
# Processing Record 2 of Set 3 | tura
# Processing Record 3 of Set 3 | aklavik
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | banda aceh
# Processing Record 6 of Set 3 | irtyshskiy
# Processing Record 7 of Set 3 | atambua
# Processing Record 8 of Set 3 | kandrian
# Processing Record 9 of Set 3 | nara
# Processing Record 10 of Set 3 | portland
# Processing Record 11 of Set 3 | tarimoro
# Processing Record 12 of Set 3 | kaitangata
# Processing Record 13 of Set 3 | labrea
# Processing Record 14 of Set 3 | port hedland
# Processing Record 15 of Set 3 | noumea
# Processing Record 16 of Set 3 | vuktyl
# Processing Record 17 of Set 3 | nanortalik
# Processing Record 18 of Set 3 | mehamn
# Processing Record 19 of Set 3 | san ramon
# Processing Record 20 of Set 3 | presidencia roque saenz pena
# Processing Record 21 of Set 3 | jibuti
# Processing Record 22 of Set 3 | melfort
# Processing Record 23 of Set 3 | prince rupert
# Processing Record 24 of Set 3 | mahebourg
# Processing Record 25 of Set 3 | road town
# Processing Record 26 of Set 3 | cockburn town
# Processing Record 27 of Set 3 | hualmay
# Processing Record 28 of Set 3 | buchanan
# Processing Record 29 of Set 3 | cardoso
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | torbay
# Processing Record 32 of Set 3 | paramonga
# Processing Record 33 of Set 3 | karema
# Processing Record 34 of Set 3 | cape town
# Processing Record 35 of Set 3 | talnakh
# Processing Record 36 of Set 3 | manbij
# Processing Record 37 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 3 | esperance
# Processing Record 39 of Set 3 | mogadishu
# Processing Record 40 of Set 3 | ust-tsilma
# Processing Record 41 of Set 3 | urupes
# Processing Record 42 of Set 3 | campo verde
# Processing Record 43 of Set 3 | jamestown
# Processing Record 44 of Set 3 | alyangula
# Processing Record 45 of Set 3 | okhotsk
# Processing Record 46 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 3 | muisne
# Processing Record 48 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 3 | cap malheureux
# Processing Record 50 of Set 3 | chapaevsk
# Processing Record 1 of Set 4 | yumen
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | arcata
# Processing Record 4 of Set 4 | kawhia
# Processing Record 5 of Set 4 | barcelos
# Processing Record 6 of Set 4 | westport
# Processing Record 7 of Set 4 | beira
# Processing Record 8 of Set 4 | lorengau
# Processing Record 9 of Set 4 | san quintin
# Processing Record 10 of Set 4 | saint anthony
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | kieta
# Processing Record 13 of Set 4 | abnub
# Processing Record 14 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 4 | tiksi
# Processing Record 16 of Set 4 | cabo san lucas
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | namatanai
# Processing Record 19 of Set 4 | meulaboh
# Processing Record 20 of Set 4 | plettenberg bay
# Processing Record 21 of Set 4 | lloydminster
# Processing Record 22 of Set 4 | cayenne
# Processing Record 23 of Set 4 | mabaruma
# Processing Record 24 of Set 4 | bambous virieux
# Processing Record 25 of Set 4 | hami
# Processing Record 26 of Set 4 | puerto leguizamo
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 4 | maua
# Processing Record 30 of Set 4 | byron bay
# Processing Record 31 of Set 4 | mount gambier
# Processing Record 32 of Set 4 | sao miguel do tapuio
# Processing Record 33 of Set 4 | ishigaki
# Processing Record 34 of Set 4 | salcininkai
# Processing Record 35 of Set 4 | grand forks
# Processing Record 36 of Set 4 | iskateley
# Processing Record 37 of Set 4 | port lincoln
# Processing Record 38 of Set 4 | oksfjord
# Processing Record 39 of Set 4 | kayerkan
# Processing Record 40 of Set 4 | georgetown
# Processing Record 41 of Set 4 | bilma
# Processing Record 42 of Set 4 | yulara
# Processing Record 43 of Set 4 | turukhansk
# Processing Record 44 of Set 4 | yeniseysk
# Processing Record 45 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 4 | inuvik
# Processing Record 47 of Set 4 | leshukonskoye
# Processing Record 48 of Set 4 | guerrero negro
# Processing Record 49 of Set 4 | yialos
# City not found. Skipping...
# Processing Record 50 of Set 4 | arraial do cabo
# Processing Record 1 of Set 5 | vardo
# Processing Record 2 of Set 5 | dingle
# Processing Record 3 of Set 5 | del rio
# Processing Record 4 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 5 of Set 5 | tilichiki
# Processing Record 6 of Set 5 | inverell
# Processing Record 7 of Set 5 | nacala
# Processing Record 8 of Set 5 | sobolevo
# Processing Record 9 of Set 5 | karratha
# Processing Record 10 of Set 5 | margate
# Processing Record 11 of Set 5 | baculin
# Processing Record 12 of Set 5 | muana
# Processing Record 13 of Set 5 | slavonski brod
# Processing Record 14 of Set 5 | riyadh
# Processing Record 15 of Set 5 | yarkovo
# Processing Record 16 of Set 5 | imari
# Processing Record 17 of Set 5 | lagoa
# Processing Record 18 of Set 5 | bose
# Processing Record 19 of Set 5 | souillac
# Processing Record 20 of Set 5 | constitucion
# Processing Record 21 of Set 5 | kununurra
# Processing Record 22 of Set 5 | kruisfontein
# Processing Record 23 of Set 5 | xichang
# Processing Record 24 of Set 5 | chikoy
# City not found. Skipping...
# Processing Record 25 of Set 5 | sao filipe
# Processing Record 26 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 5 | sayyan
# Processing Record 28 of Set 5 | guatire
# Processing Record 29 of Set 5 | asfi
# Processing Record 30 of Set 5 | general pico
# Processing Record 31 of Set 5 | pokhara
# Processing Record 32 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 5 | gamba
# Processing Record 34 of Set 5 | denpasar
# Processing Record 35 of Set 5 | norman wells
# Processing Record 36 of Set 5 | marsh harbour
# Processing Record 37 of Set 5 | thinadhoo
# Processing Record 38 of Set 5 | gat
# Processing Record 39 of Set 5 | nassjo
# Processing Record 40 of Set 5 | pedasi
# Processing Record 41 of Set 5 | bethel
# Processing Record 42 of Set 5 | biak
# Processing Record 43 of Set 5 | ihosy
# Processing Record 44 of Set 5 | krasnovishersk
# Processing Record 45 of Set 5 | bagan
# Processing Record 46 of Set 5 | severo-kurilsk
# Processing Record 47 of Set 5 | viedma
# Processing Record 48 of Set 5 | uchiza
# Processing Record 49 of Set 5 | geraldton
# Processing Record 50 of Set 5 | fairbanks
# Processing Record 1 of Set 6 | porto seguro
# Processing Record 2 of Set 6 | aitape
# Processing Record 3 of Set 6 | camalu
# Processing Record 4 of Set 6 | mareeba
# Processing Record 5 of Set 6 | nome
# Processing Record 6 of Set 6 | flin flon
# Processing Record 7 of Set 6 | kvarkeno
# Processing Record 8 of Set 6 | hithadhoo
# Processing Record 9 of Set 6 | adre
# Processing Record 10 of Set 6 | provideniya
# Processing Record 11 of Set 6 | almeirim
# Processing Record 12 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 6 | uige
# Processing Record 14 of Set 6 | berlevag
# Processing Record 15 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 16 of Set 6 | henties bay
# Processing Record 17 of Set 6 | krasnoselkup
# Processing Record 18 of Set 6 | iqaluit
# Processing Record 19 of Set 6 | lensk
# Processing Record 20 of Set 6 | alexandria
# Processing Record 21 of Set 6 | pisco
# Processing Record 22 of Set 6 | beloha
# Processing Record 23 of Set 6 | hobyo
# Processing Record 24 of Set 6 | sao jose do calcado
# Processing Record 25 of Set 6 | mumford
# Processing Record 26 of Set 6 | avera
# Processing Record 27 of Set 6 | kerema
# Processing Record 28 of Set 6 | leningradskiy
# Processing Record 29 of Set 6 | saint-philippe
# Processing Record 30 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 31 of Set 6 | naron
# Processing Record 32 of Set 6 | wad rawah
# Processing Record 33 of Set 6 | nikolskoye
# Processing Record 34 of Set 6 | toropets
# Processing Record 35 of Set 6 | zurrieq
# Processing Record 36 of Set 6 | kaliua
# Processing Record 37 of Set 6 | baherden
# Processing Record 38 of Set 6 | port hawkesbury
# Processing Record 39 of Set 6 | tulum
# Processing Record 40 of Set 6 | xixiang
# Processing Record 41 of Set 6 | cayeli
# Processing Record 42 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 6 | oakley
# Processing Record 44 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 6 | yeletskiy
# City not found. Skipping...
# Processing Record 46 of Set 6 | goba
# Processing Record 47 of Set 6 | sao joao do piaui
# Processing Record 48 of Set 6 | pangody
# Processing Record 49 of Set 6 | kavieng
# Processing Record 50 of Set 6 | upernavik
# Processing Record 1 of Set 7 | kirakira
# Processing Record 2 of Set 7 | loyga
# Processing Record 3 of Set 7 | lompoc
# Processing Record 4 of Set 7 | husavik
# Processing Record 5 of Set 7 | atasu
# Processing Record 6 of Set 7 | boende
# Processing Record 7 of Set 7 | ahipara
# Processing Record 8 of Set 7 | tunxi
# City not found. Skipping...
# Processing Record 9 of Set 7 | sur
# Processing Record 10 of Set 7 | ostersund
# Processing Record 11 of Set 7 | roebourne
# Processing Record 12 of Set 7 | ilulissat
# Processing Record 13 of Set 7 | duldurga
# Processing Record 14 of Set 7 | ostrovnoy
# Processing Record 15 of Set 7 | atbasar
# Processing Record 16 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 17 of Set 7 | lata
# Processing Record 18 of Set 7 | carnarvon
# Processing Record 19 of Set 7 | lavrentiya
# Processing Record 20 of Set 7 | turbat
# Processing Record 21 of Set 7 | bathsheba
# Processing Record 22 of Set 7 | fortuna
# Processing Record 23 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 7 | batsfjord
# Processing Record 25 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 26 of Set 7 | verkhnechusovskiye gorodki
# Processing Record 27 of Set 7 | saint george
# Processing Record 28 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 7 | nizhnevartovsk
# Processing Record 30 of Set 7 | talaya
# Processing Record 31 of Set 7 | taltal
# Processing Record 32 of Set 7 | mount isa
# Processing Record 33 of Set 7 | burica
# City not found. Skipping...
# Processing Record 34 of Set 7 | ekhabi
# Processing Record 35 of Set 7 | surt
# Processing Record 36 of Set 7 | el coco
# Processing Record 37 of Set 7 | susanville
# Processing Record 38 of Set 7 | beringovskiy
# Processing Record 39 of Set 7 | kashi
# Processing Record 40 of Set 7 | thai nguyen
# Processing Record 41 of Set 7 | excelsior springs
# Processing Record 42 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 7 | rio gallegos
# Processing Record 44 of Set 7 | fort nelson
# Processing Record 45 of Set 7 | erenhot
# Processing Record 46 of Set 7 | pacific grove
# Processing Record 47 of Set 7 | saskylakh
# Processing Record 48 of Set 7 | san cristobal
# Processing Record 49 of Set 7 | iraucuba
# Processing Record 50 of Set 7 | bolobo
# Processing Record 1 of Set 8 | port augusta
# Processing Record 2 of Set 8 | kroderen
# City not found. Skipping...
# Processing Record 3 of Set 8 | changping
# Processing Record 4 of Set 8 | coquimbo
# Processing Record 5 of Set 8 | wencheng
# Processing Record 6 of Set 8 | camacha
# Processing Record 7 of Set 8 | russell
# Processing Record 8 of Set 8 | nantucket
# Processing Record 9 of Set 8 | shenjiamen
# Processing Record 10 of Set 8 | lasa
# Processing Record 11 of Set 8 | mitsamiouli
# Processing Record 12 of Set 8 | kahului
# Processing Record 13 of Set 8 | juliaca
# Processing Record 14 of Set 8 | clyde river
# Processing Record 15 of Set 8 | pacasmayo
# Processing Record 16 of Set 8 | samarai
# Processing Record 17 of Set 8 | pangai
# Processing Record 18 of Set 8 | yining
# Processing Record 19 of Set 8 | mwene-ditu
# Processing Record 20 of Set 8 | marsabit
# Processing Record 21 of Set 8 | moba
# Processing Record 22 of Set 8 | kodinsk
# Processing Record 23 of Set 8 | bulri
# Processing Record 24 of Set 8 | vao
# Processing Record 25 of Set 8 | guapore
# Processing Record 26 of Set 8 | belaya gora
# Processing Record 27 of Set 8 | vestmannaeyjar
# Processing Record 28 of Set 8 | ligayan
# Processing Record 29 of Set 8 | harper
# Processing Record 30 of Set 8 | alta floresta
# Processing Record 31 of Set 8 | thompson
# Processing Record 32 of Set 8 | youhao
# Processing Record 33 of Set 8 | qaanaaq
# Processing Record 34 of Set 8 | parainen
# Processing Record 35 of Set 8 | scarborough
# Processing Record 36 of Set 8 | san patricio
# Processing Record 37 of Set 8 | dauphin
# Processing Record 38 of Set 8 | waipawa
# Processing Record 39 of Set 8 | villarrica
# Processing Record 40 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 8 | laguna
# Processing Record 42 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 43 of Set 8 | krasnyy chikoy
# Processing Record 44 of Set 8 | seydi
# Processing Record 45 of Set 8 | huesca
# Processing Record 46 of Set 8 | issia
# Processing Record 47 of Set 8 | garowe
# Processing Record 48 of Set 8 | mantua
# Processing Record 49 of Set 8 | shihezi
# Processing Record 50 of Set 8 | adwa
# Processing Record 1 of Set 9 | miranda
# Processing Record 2 of Set 9 | wanning
# Processing Record 3 of Set 9 | khingansk
# Processing Record 4 of Set 9 | ponta do sol
# Processing Record 5 of Set 9 | nishihara
# Processing Record 6 of Set 9 | aasiaat
# Processing Record 7 of Set 9 | revelstoke
# Processing Record 8 of Set 9 | lazaro cardenas
# Processing Record 9 of Set 9 | urusha
# Processing Record 10 of Set 9 | haines junction
# Processing Record 11 of Set 9 | kurilsk
# Processing Record 12 of Set 9 | hasaki
# Processing Record 13 of Set 9 | cherskiy
# Processing Record 14 of Set 9 | conceicao do araguaia
# Processing Record 15 of Set 9 | mecca
# Processing Record 16 of Set 9 | sisimiut
# Processing Record 17 of Set 9 | moose factory
# Processing Record 18 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 19 of Set 9 | falun
# Processing Record 20 of Set 9 | itaituba
# Processing Record 21 of Set 9 | broome
# Processing Record 22 of Set 9 | babu
# Processing Record 23 of Set 9 | ippy
# Processing Record 24 of Set 9 | marsa matruh
# Processing Record 25 of Set 9 | galle
# Processing Record 26 of Set 9 | kavaratti
# Processing Record 27 of Set 9 | yarega
# Processing Record 28 of Set 9 | vangaindrano
# Processing Record 29 of Set 9 | teguldet
# Processing Record 30 of Set 9 | ambon
# Processing Record 31 of Set 9 | ouadda
# Processing Record 32 of Set 9 | akureyri
# Processing Record 33 of Set 9 | nuuk
# Processing Record 34 of Set 9 | marrakesh
# Processing Record 35 of Set 9 | sisophon
# Processing Record 36 of Set 9 | inhambane
# Processing Record 37 of Set 9 | naryan-mar
# Processing Record 38 of Set 9 | myitkyina
# Processing Record 39 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 9 | east london
# Processing Record 41 of Set 9 | saint-augustin
# Processing Record 42 of Set 9 | faanui
# Processing Record 43 of Set 9 | pontarlier
# Processing Record 44 of Set 9 | axim
# Processing Record 45 of Set 9 | palana
# Processing Record 46 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 9 | empangeni
# Processing Record 48 of Set 9 | canakkale
# Processing Record 49 of Set 9 | poum
# Processing Record 50 of Set 9 | north bay
# Processing Record 1 of Set 10 | broken hill
# Processing Record 2 of Set 10 | sandwick
# Processing Record 3 of Set 10 | sechura
# Processing Record 4 of Set 10 | ferentino
# Processing Record 5 of Set 10 | franklin
# Processing Record 6 of Set 10 | sembe
# Processing Record 7 of Set 10 | linqiong
# Processing Record 8 of Set 10 | chicama
# Processing Record 9 of Set 10 | reconquista
# Processing Record 10 of Set 10 | ayorou
# Processing Record 11 of Set 10 | chesterton
# Processing Record 12 of Set 10 | fevik
# Processing Record 13 of Set 10 | tateyama
# Processing Record 14 of Set 10 | buraydah
# Processing Record 15 of Set 10 | shingu
# Processing Record 16 of Set 10 | umm lajj
# Processing Record 17 of Set 10 | flinders
# Processing Record 18 of Set 10 | seoul
# Processing Record 19 of Set 10 | coos bay
# Processing Record 20 of Set 10 | evanston
# Processing Record 21 of Set 10 | sept-iles
# Processing Record 22 of Set 10 | boromo
# Processing Record 23 of Set 10 | san francisco morazan
# City not found. Skipping...
# Processing Record 24 of Set 10 | panacan
# Processing Record 25 of Set 10 | mokrous
# Processing Record 26 of Set 10 | kudahuvadhoo
# Processing Record 27 of Set 10 | la ronge
# Processing Record 28 of Set 10 | vila do maio
# Processing Record 29 of Set 10 | grande prairie
# Processing Record 30 of Set 10 | banjar
# Processing Record 31 of Set 10 | chokwe
# Processing Record 32 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 10 | superior
# Processing Record 34 of Set 10 | cartagena
# Processing Record 35 of Set 10 | yarensk
# Processing Record 36 of Set 10 | plainview
# Processing Record 37 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 38 of Set 10 | nelson bay
# Processing Record 39 of Set 10 | bereda
# Processing Record 40 of Set 10 | rocha
# Processing Record 41 of Set 10 | domoni
# Processing Record 42 of Set 10 | nassau
# Processing Record 43 of Set 10 | hambantota
# Processing Record 44 of Set 10 | myanaung
# Processing Record 45 of Set 10 | grenfell
# Processing Record 46 of Set 10 | tefe
# Processing Record 47 of Set 10 | hervey bay
# Processing Record 48 of Set 10 | andra
# Processing Record 49 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 10 | ulladulla
# Processing Record 1 of Set 11 | progreso
# Processing Record 2 of Set 11 | ishim
# Processing Record 3 of Set 11 | chicaman
# Processing Record 4 of Set 11 | genhe
# Processing Record 5 of Set 11 | cascais
# Processing Record 6 of Set 11 | kerman
# Processing Record 7 of Set 11 | troitskoye
# Processing Record 8 of Set 11 | kotelnich
# Processing Record 9 of Set 11 | kuloy
# Processing Record 10 of Set 11 | abu samrah
# Processing Record 11 of Set 11 | srednekolymsk
# Processing Record 12 of Set 11 | codrington
# Processing Record 13 of Set 11 | vanimo
# Processing Record 14 of Set 11 | sakakah
# Processing Record 15 of Set 11 | puerto escondido
# Processing Record 16 of Set 11 | pijijiapan
# Processing Record 17 of Set 11 | tobermory
# Processing Record 18 of Set 11 | blairmore
# Processing Record 19 of Set 11 | chengmai
# City not found. Skipping...
# Processing Record 20 of Set 11 | alamogordo
# Processing Record 21 of Set 11 | vila franca do campo
# Processing Record 22 of Set 11 | koraput
# Processing Record 23 of Set 11 | nicoya
# Processing Record 24 of Set 11 | sechelt
# Processing Record 25 of Set 11 | zhezkazgan
# Processing Record 26 of Set 11 | arroyo
# Processing Record 27 of Set 11 | kyra
# Processing Record 28 of Set 11 | haapiti
# Processing Record 29 of Set 11 | maniitsoq
# Processing Record 30 of Set 11 | erzin
# Processing Record 31 of Set 11 | kasongo-lunda
# Processing Record 32 of Set 11 | verkhoyansk
# Processing Record 33 of Set 11 | isangel
# Processing Record 34 of Set 11 | ye
# City not found. Skipping...
# Processing Record 35 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 11 | paka
# Processing Record 37 of Set 11 | la spezia
# Processing Record 38 of Set 11 | hovd
# Processing Record 39 of Set 11 | igarka
# Processing Record 40 of Set 11 | mendi
# Processing Record 41 of Set 11 | abaza
# Processing Record 42 of Set 11 | mwingi
# Processing Record 43 of Set 11 | tautira
# Processing Record 44 of Set 11 | narsaq
# Processing Record 45 of Set 11 | anadyr
# Processing Record 46 of Set 11 | urozhayne
# City not found. Skipping...
# Processing Record 47 of Set 11 | roma
# Processing Record 48 of Set 11 | nelson
# Processing Record 49 of Set 11 | pueblo nuevo
# Processing Record 50 of Set 11 | aykhal
# Processing Record 1 of Set 12 | soe
# Processing Record 2 of Set 12 | springville
# Processing Record 3 of Set 12 | homer
# Processing Record 4 of Set 12 | touros
# Processing Record 5 of Set 12 | alofi
# Processing Record 6 of Set 12 | te anau
# Processing Record 7 of Set 12 | kailua
# Processing Record 8 of Set 12 | kilindoni
# Processing Record 9 of Set 12 | lourdes
# Processing Record 10 of Set 12 | tessalit
# Processing Record 11 of Set 12 | dunedin
# Processing Record 12 of Set 12 | hurghada
# Processing Record 13 of Set 12 | molochnoye
# Processing Record 14 of Set 12 | chumikan
# Processing Record 15 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 16 of Set 12 | birjand
# Processing Record 17 of Set 12 | ginda
# Processing Record 18 of Set 12 | iwanai
# Processing Record 19 of Set 12 | opuwo
# Processing Record 20 of Set 12 | tisul
# Processing Record 21 of Set 12 | prince george
# Processing Record 22 of Set 12 | adrar
# Processing Record 23 of Set 12 | ngunguru
# Processing Record 24 of Set 12 | nizhniy tsasuchey
# Processing Record 25 of Set 12 | luwuk
# Processing Record 26 of Set 12 | cap-aux-meules
# Processing Record 27 of Set 12 | egvekinot
# Processing Record 28 of Set 12 | chernyshevskiy
# Processing Record 29 of Set 12 | vadso
# Processing Record 30 of Set 12 | barnova
# Processing Record 31 of Set 12 | la mira
# Processing Record 32 of Set 12 | todos santos
# Processing Record 33 of Set 12 | ilek
# Processing Record 34 of Set 12 | xining
# Processing Record 35 of Set 12 | garden city
# Processing Record 36 of Set 12 | gayeri
# Processing Record 37 of Set 12 | bud
# Processing Record 38 of Set 12 | mawlaik
# Processing Record 39 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 40 of Set 12 | amga
# Processing Record 41 of Set 12 | poronaysk
# Processing Record 42 of Set 12 | mutoko
# Processing Record 43 of Set 12 | eureka
# Processing Record 44 of Set 12 | morondava
# Processing Record 45 of Set 12 | chara
# Processing Record 46 of Set 12 | khandyga
# Processing Record 47 of Set 12 | tartagal
# Processing Record 48 of Set 12 | betera
# Processing Record 49 of Set 12 | kupang
# Processing Record 50 of Set 12 | monterey
# Processing Record 1 of Set 13 | carlos antonio lopez
# Processing Record 2 of Set 13 | agadez
# Processing Record 3 of Set 13 | bhadrachalam
# Processing Record 4 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 13 | aldan
# Processing Record 6 of Set 13 | andenes
# Processing Record 7 of Set 13 | sistranda
# Processing Record 8 of Set 13 | dong xoai
# Processing Record 9 of Set 13 | piacabucu
# Processing Record 10 of Set 13 | at-bashi
# Processing Record 11 of Set 13 | sabang
# Processing Record 12 of Set 13 | sao miguel do araguaia
# Processing Record 13 of Set 13 | san rafael
# Processing Record 14 of Set 13 | tazovskiy
# Processing Record 15 of Set 13 | quimper
# Processing Record 16 of Set 13 | mount pleasant
# Processing Record 17 of Set 13 | zheleznogorsk-ilimskiy
# Processing Record 18 of Set 13 | sioux lookout
# Processing Record 19 of Set 13 | kandi
# Processing Record 20 of Set 13 | olafsvik
# Processing Record 21 of Set 13 | campina grande do sul
# Processing Record 22 of Set 13 | miloi
# City not found. Skipping...
# Processing Record 23 of Set 13 | soyo
# Processing Record 24 of Set 13 | sampit
# Processing Record 25 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 26 of Set 13 | castelo do piaui
# Processing Record 27 of Set 13 | duz
# City not found. Skipping...
# Processing Record 28 of Set 13 | pathalgaon
# Processing Record 29 of Set 13 | oltenita
# Processing Record 30 of Set 13 | oskaloosa
# Processing Record 31 of Set 13 | sao gabriel da cachoeira
# Processing Record 32 of Set 13 | bandarbeyla
# Processing Record 33 of Set 13 | erdemli
# Processing Record 34 of Set 13 | agva
# City not found. Skipping...
# Processing Record 35 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 36 of Set 13 | stonewall
# Processing Record 37 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 38 of Set 13 | thabazimbi
# Processing Record 39 of Set 13 | leninogorsk
# Processing Record 40 of Set 13 | hermiston
# Processing Record 41 of Set 13 | walvis bay
# Processing Record 42 of Set 13 | palmeira das missoes
# Processing Record 43 of Set 13 | chapais
# Processing Record 44 of Set 13 | haverfordwest
# Processing Record 45 of Set 13 | brenham
# Processing Record 46 of Set 13 | karymskoye
# Processing Record 47 of Set 13 | pocone
# Processing Record 48 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 49 of Set 13 | shikhazany
# Processing Record 50 of Set 13 | luanda
# Processing Record 1 of Set 14 | comodoro rivadavia
# Processing Record 2 of Set 14 | northam
# Processing Record 3 of Set 14 | balykshi
# Processing Record 4 of Set 14 | parana
# Processing Record 5 of Set 14 | ust-nera
# Processing Record 6 of Set 14 | santa marta
# Processing Record 7 of Set 14 | forestville
# Processing Record 8 of Set 14 | ploemeur
# Processing Record 9 of Set 14 | visby
# Processing Record 10 of Set 14 | san roque
# Processing Record 11 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 14 | altay
# Processing Record 14 of Set 14 | tigil
# Processing Record 15 of Set 14 | marmora
# Processing Record 16 of Set 14 | gibara
# Processing Record 17 of Set 14 | paulo ramos
# Processing Record 18 of Set 14 | dotnuva
# Processing Record 19 of Set 14 | victor harbor
# Processing Record 20 of Set 14 | ingersoll
# Processing Record 21 of Set 14 | atar
# Processing Record 22 of Set 14 | caucaia
# Processing Record 23 of Set 14 | bombay
# Processing Record 24 of Set 14 | chuy
# Processing Record 25 of Set 14 | roald
# Processing Record 26 of Set 14 | santa cruz
# Processing Record 27 of Set 14 | billings
# Processing Record 28 of Set 14 | iiyama
# Processing Record 29 of Set 14 | shimoda
# Processing Record 30 of Set 14 | san alberto
# Processing Record 31 of Set 14 | salaga
# Processing Record 32 of Set 14 | kuching
# Processing Record 33 of Set 14 | pierre
# Processing Record 34 of Set 14 | viransehir
# Processing Record 35 of Set 14 | carauari
# Processing Record 36 of Set 14 | kushima
# Processing Record 37 of Set 14 | helong
# Processing Record 38 of Set 14 | kenai
# Processing Record 39 of Set 14 | merritt
# Processing Record 40 of Set 14 | artyom
# Processing Record 41 of Set 14 | borovoy
# Processing Record 42 of Set 14 | shu
# Processing Record 43 of Set 14 | yuzhno-kurilsk
# Processing Record 44 of Set 14 | rawlins
# Processing Record 45 of Set 14 | carutapera
# Processing Record 46 of Set 14 | huarmey
# Processing Record 47 of Set 14 | mae hong son
# Processing Record 48 of Set 14 | faya
# Processing Record 49 of Set 14 | moiyabana
# City not found. Skipping...
# Processing Record 50 of Set 14 | la sarre
# Processing Record 1 of Set 15 | porbandar
# Processing Record 2 of Set 15 | kungurtug
# Processing Record 3 of Set 15 | kakonko
# Processing Record 4 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 15 | tingrela
# City not found. Skipping...
# Processing Record 6 of Set 15 | tagusao
# Processing Record 7 of Set 15 | kysyl-syr
# Processing Record 8 of Set 15 | antibes
# Processing Record 9 of Set 15 | orlik
# Processing Record 10 of Set 15 | port hardy
# Processing Record 11 of Set 15 | balaipungut
# Processing Record 12 of Set 15 | anloga
# Processing Record 13 of Set 15 | oktyabrskiy
# Processing Record 14 of Set 15 | quarai
# Processing Record 15 of Set 15 | a
# City not found. Skipping...
# Processing Record 16 of Set 15 | mengcheng
# Processing Record 17 of Set 15 | shaowu
# Processing Record 18 of Set 15 | alice springs
# Processing Record 19 of Set 15 | xuddur
# Processing Record 20 of Set 15 | mayo
# Processing Record 21 of Set 15 | mana
# Processing Record 22 of Set 15 | gorgan
# Processing Record 23 of Set 15 | ilebo
# Processing Record 24 of Set 15 | chalons-en-champagne
# Processing Record 25 of Set 15 | stornoway
# Processing Record 26 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 27 of Set 15 | lenger
# Processing Record 28 of Set 15 | lake havasu city
# Processing Record 29 of Set 15 | kizema
# Processing Record 30 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 15 | itarema
# Processing Record 32 of Set 15 | yarada
# Processing Record 33 of Set 15 | lubyany
# Processing Record 34 of Set 15 | lewistown
# Processing Record 35 of Set 15 | jardim
# Processing Record 36 of Set 15 | manitouwadge
# Processing Record 37 of Set 15 | dongobesh
# Processing Record 38 of Set 15 | yar-sale
# Processing Record 39 of Set 15 | darhan
# Processing Record 40 of Set 15 | berdigestyakh
# Processing Record 41 of Set 15 | marawi
# Processing Record 42 of Set 15 | nalut
# Processing Record 43 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 44 of Set 15 | newberry
# Processing Record 45 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 46 of Set 15 | saint-pierre
# Processing Record 47 of Set 15 | grindavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 679

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)city_data_df.head(15)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      New Norfolk -42.7826  147.0587     60.93        77         100
# 1         Hanamaki  39.3833  141.1167     46.09        94          98
# 2   Rio De Janeiro -22.9028  -43.2075     87.75        67           0
# 3            Muros  42.7762   -9.0603     69.10        57           7
# 4             Abha  18.2164   42.5053     69.62        56          40
# 5      Pangnirtung  66.1451  -65.7125     24.80        86         100
# 6      Port Alfred -33.5906   26.8910     63.18        83           5
# 7           Atuona  -9.8000 -139.0333     78.69        75          48
# 8          Rikitea -23.1203 -134.9692     76.37        72          29
# 9           Namibe -15.1961   12.1522     76.03        74          10
# 10          Padang  -0.9492  100.3543     75.25        87          97
# 11      Nouadhibou  20.9310  -17.0347     73.38        68           0
# 12        Hermanus -34.4187   19.2345     64.80        81           0
# 13           Ancud -41.8697  -73.8203     55.29        80          83
# 14          Albany  42.6001  -73.9662     64.62        32           4
#
#     Wind Speed   Current Weather
# 0         1.99   overcast clouds
# 1         1.70   overcast clouds
# 2         5.75         clear sky
# 3        17.09         clear sky
# 4         6.91        light rain
# 5         2.30   overcast clouds
# 6         1.99         clear sky
# 7        12.82  scattered clouds
# 8         6.06  scattered clouds
# 9        16.46         clear sky
# 10        2.51        light rain
# 11       20.71              dust
# 12       10.07         clear sky
# 13        1.83     broken clouds
# 14        1.99         clear sky

# %%
output_data_file = "weather_data/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
