# %%
# Dependencies
import requests
from confignyt import api_key

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
search_filters = "Portland" + "&" + "pub_date=20210101" + "&" + "end_date=20210105" 

# Build url
search_url = url + "&api-key=" + api_key + "&q=" + search_filters 
#queryULR using fstring: f"{url}?api-key={api_key}&q={search_filters}
print(search_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?&api-key=p6i615rpAnWR2y6o0f7uU9S84FAG26IM&q=Portland&pub_date=20210101&end_date=20210105

# %%
# Retrieve articles
articles = requests.get(search_url).json()
#turn these into a list
articles_list = [article for article in articles["response"]["docs"]]
print(articles_list)
# Out:
# [{'abstract': 'The family lost its home of 60 years to foreclosure after taking out mortgages to pay legal fees. Some advocates say gentrification and skyrocketing prices are driving Black families out of the city.', 'web_url': 'https://www.nytimes.com/2020/12/10/us/portland-eviction-protests.html', 'snippet': 'The family lost its home of 60 years to foreclosure after taking out mortgages to pay legal fees. Some advocates say gentrification and skyrocketing prices are driving Black families out of the city.', 'lead_paragraph': 'A standoff between the police and protesters over a mixed-race family’s eviction in Portland, Ore., is stirring up old ghosts of segregation and redlining from the 20th century, when Black families moved in for jobs and found that there were only certain places they could live.', 'print_section': 'A', 'print_page': '17', 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'ima
# ...

# %%
print("Your reading list")
for article in articles_list:
    print(article["web_url"])
# Out:
# Your reading list
# https://www.nytimes.com/2020/12/10/us/portland-eviction-protests.html
# https://www.nytimes.com/2021/01/04/sports/basketball/stephen-curry-62-points.html
# https://www.nytimes.com/2020/12/22/us/police-misconduct-discipline.html
# https://www.nytimes.com/2020/12/21/dining/kwanzaa-celebration.html
# https://www.nytimes.com/2020/12/21/sports/basketball/nba-western-conference-preview.html
# https://www.nytimes.com/2020/11/25/sports/basketball/nba-free-agency-derrick-jones.html
# https://www.nytimes.com/slideshow/2020/11/18/realestate/what-you-get-for-1-7-million.html
# https://www.nytimes.com/2020/11/18/realestate/1-7-million-homes-in-illinois-massachusetts-and-oregon.html
# https://www.nytimes.com/2020/11/06/upshot/oregon-universal-preschool-election.html
# https://www.nytimes.com/2020/11/05/us/election-protests-portland-minnesota-arizona.html

# %%
for article in articles_list:
    print(f"A snippet from: {article["snippet"]}")
    print('------------')
# Out:
#   File "/var/folders/l4/m3sdn1fd4k1ggbmylkh5lpw80000gp/T/ipykernel_23072/2514027996.py", line 2
#     print(f"A snippet from: {article["snippet"]}")
#                                             ^
# SyntaxError: invalid syntax

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param
